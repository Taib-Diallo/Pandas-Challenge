# %% [markdown]
# # Observations:
# 1. All of the top 5 performing schools are charter school, while the bottom 5 performing schools are district.
# 2. While both the top and bottom 5 schools have similar reading scores, the math scores is really where the biggest difference occurs.
# 3. Charter schools have higher scores than district school all across the board.
# 4. There is a negative correlation between the school size and overall passing rate.

# %%
import pandas as pd

# %%
# File to Load (Remember to Change These)
school_data_to_load = "schools_complete.csv"
student_data_to_load = "students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# creating a dataframe
combined_df = school_data_complete
combined_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
#total number of schools
schools = len(combined_df.groupby('school_name'))
print(schools)
# Out:
# 15

# %%
#total number of students
students = len(combined_df)
print(students)
# Out:
# 39170

# %%
#total budget
budget = school_data['budget'].sum()
print(budget)
# Out:
# 24649428

# %%
avg_math = student_data['math_score'].mean()
print(avg_math)
# Out:
# 78.98537145774827

# %%
avg_reading = student_data['reading_score'].mean()
print(avg_reading)
# Out:
# 81.87784018381414

# %%
student_data['passed_math'] = student_data['math_score'] >= 70

math_passed = sum(student_data['passed_math'])
#print(math_passed)

# %%
percent_pm = ((math_passed / students) * 100)
print(percent_pm)
# Out:
# 74.9808526933878

# %%
student_data['passed_reading'] = student_data['reading_score'] >= 70
reading_passed = sum(student_data['passed_reading'])
print(reading_passed)
# Out:
# 33610

# %%
percent_pr = ((reading_passed/students)* 100)
print(percent_pr)
# Out:
# 85.80546336482001

# %%
student_data['passed_both'] = (student_data['reading_score'] >=70) & (student_data['math_score'] >=70)
both_passed = sum(student_data['passed_both'])
#print(both_passed)

# %%
percent_pb = ((both_passed/ students)* 100)
print(percent_pb)
# Out:
# 65.17232575950983

# %%
district_df = pd.DataFrame([{'Total Schools': schools, 'Total Students':students, 'Total Budget':budget, 'Average Math Score':avg_math, 'Average Reading Score':avg_reading, '% Passing Math':percent_pm, '% Passing Reading':percent_pr, '% Overall Passing':percent_pb}])
district_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
school_table_sum_copy = combined_df.copy()
school_table_sum_copy
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %% [markdown]
# # Deleting any extra columns I won't need.

# %%
del school_table_sum_copy['student_name']

# %%
del school_table_sum_copy['gender']

# %%
del school_table_sum_copy['grade']

# %%
del school_table_sum_copy['School ID']

# %%
school_table_sum_copy.columns = ['Student ID', 'School Name','Reading Score', 'Math Score', 'School Type', 'Total Students', 'Total School Budget']

# %%
school_table_sum_copy
# Out:
#        Student ID         School Name  Reading Score  Math Score School Type  \
# 0               0   Huang High School             66          79    District
# 1               1   Huang High School             94          61    District
# 2               2   Huang High School             90          60    District
# 3               3   Huang High School             67          58    District
# 4               4   Huang High School             97          84    District
# ...           ...                 ...            ...         ...         ...
# 39165       39165  Thomas High School             99          90     Charter
# 39166       39166  Thomas High School             95          70     Charter
# 39167       39167  Thomas High School             73          84     Charter
# 39168       39168  Thomas High School             99          90     Charter
# 39169       39169  Thomas High School             95          75     Charter
#
#        Total Students  Total School Budget
# ...

# %% [markdown]
# # Reorganizing my table

# %%
organized_school_table = school_table_sum_copy[['School Name','Student ID','School Type', 'Total Students', 'Total School Budget', 'Reading Score', 'Math Score']]
organized_school_table
# Out:
#               School Name  Student ID School Type  Total Students  \
# 0       Huang High School           0    District            2917
# 1       Huang High School           1    District            2917
# 2       Huang High School           2    District            2917
# 3       Huang High School           3    District            2917
# 4       Huang High School           4    District            2917
# ...                   ...         ...         ...             ...
# 39165  Thomas High School       39165     Charter            1635
# 39166  Thomas High School       39166     Charter            1635
# 39167  Thomas High School       39167     Charter            1635
# 39168  Thomas High School       39168     Charter            1635
# 39169  Thomas High School       39169     Charter            1635
#
#        Total School Budget  Reading Score  Math Score
# 0                  1910635             66          79
# 1                  1910635             94          61
# ...

# %%
organized_school_table['Per Student Budget'] = organized_school_table['Total School Budget']/ organized_school_table['Total Students']
# Out:
# C:\Users\Owner\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
organized_school_table
# Out:
#               School Name  Student ID School Type  Total Students  \
# 0       Huang High School           0    District            2917
# 1       Huang High School           1    District            2917
# 2       Huang High School           2    District            2917
# 3       Huang High School           3    District            2917
# 4       Huang High School           4    District            2917
# ...                   ...         ...         ...             ...
# 39165  Thomas High School       39165     Charter            1635
# 39166  Thomas High School       39166     Charter            1635
# 39167  Thomas High School       39167     Charter            1635
# 39168  Thomas High School       39168     Charter            1635
# 39169  Thomas High School       39169     Charter            1635
#
#        Total School Budget  Reading Score  Math Score  Per Student Budget
# 0                  1910635             66          79               655.0
# ...

# %%
school_math_avg = organized_school_table.loc[organized_school_table['Math Score'] >= 70].groupby('School Name')
school_math_avg.head()
# Out:
#               School Name  Student ID School Type  Total Students  \
# 0       Huang High School           0    District            2917
# 4       Huang High School           4    District            2917
# 5       Huang High School           5    District            2917
# 6       Huang High School           6    District            2917
# 8       Huang High School           8    District            2917
# ...                   ...         ...         ...             ...
# 37535  Thomas High School       37535     Charter            1635
# 37536  Thomas High School       37536     Charter            1635
# 37537  Thomas High School       37537     Charter            1635
# 37539  Thomas High School       37539     Charter            1635
# 37540  Thomas High School       37540     Charter            1635
#
#        Total School Budget  Reading Score  Math Score  Per Student Budget
# 0                  1910635             66          79               655.0
# ...

# %%
school_reading_avg = organized_school_table.loc[organized_school_table['Reading Score'] >= 70].groupby('School Name')
school_overall_avg = organized_school_table.loc[(organized_school_table['Math Score'] >= 70) & (organized_school_table['Reading Score'] >= 70)].groupby('School Name')

# %%
#grouping by school
school_groupby = organized_school_table.groupby('School Name')

#school district dataframe
school_summary_df = pd.DataFrame({
    'School Type': school_groupby['School Type'].unique().astype(str),
    'Total Students': school_groupby['Student ID'].count(),
    'Total School Budget': school_groupby['Total School Budget'].unique().astype(float),
    'Per Student Budget': school_groupby['Per Student Budget'].unique().astype(float),
    'Average Math Score': school_groupby['Math Score'].mean(),
    'Average Reading Score':school_groupby['Reading Score'].mean(),
    '% Passing Math': (school_math_avg['Math Score'].count()/school_groupby['Total Students'].unique().astype(float)) *100,
    '% Passing Reading': (school_reading_avg['Reading Score'].count()/ school_groupby['Total Students'].unique().astype(float))* 100,
    '% Overall Passing': (school_overall_avg['Reading Score'].count()/ school_groupby['Total Students'].unique().astype(float))* 100
    
})
school_summary_df
# Out:
#                         School Type  Total Students  Total School Budget  \
# School Name
# Bailey High School     ['District']            4976            3124928.0
# Cabrera High School     ['Charter']            1858            1081356.0
# Figueroa High School   ['District']            2949            1884411.0
# Ford High School       ['District']            2739            1763916.0
# Griffin High School     ['Charter']            1468             917500.0
# Hernandez High School  ['District']            4635            3022020.0
# Holden High School      ['Charter']             427             248087.0
# Huang High School      ['District']            2917            1910635.0
# Johnson High School    ['District']            4761            3094650.0
# Pena High School        ['Charter']             962             585858.0
# Rodriguez High School  ['District']            3999            2547363.0
# Shelton High School     ['Charter']            1761            1056600.0
# ...

# %%
#Top 5 performing schools sorted by % overall passing

top_five = school_summary_df.sort_values('% Overall Passing', ascending = False)
top_five.head(5)
# Out:
#                      School Type  Total Students  Total School Budget  \
# School Name
# Cabrera High School  ['Charter']            1858            1081356.0
# Thomas High School   ['Charter']            1635            1043130.0
# Griffin High School  ['Charter']            1468             917500.0
# Wilson High School   ['Charter']            2283            1319574.0
# Pena High School     ['Charter']             962             585858.0
#
#                      Per Student Budget  Average Math Score  \
# School Name
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# School Name
# ...

# %%
# Bottom 5 perfoming school based on % overall passing

bottom_five = school_summary_df.sort_values('% Overall Passing', ascending = True)
bottom_five.head(5)
# Out:
#                       School Type  Total Students  Total School Budget  \
# School Name
# Rodriguez High School  [District]            3999            2547363.0
# Figueroa High School   [District]            2949            1884411.0
# Huang High School      [District]            2917            1910635.0
# Hernandez High School  [District]            4635            3022020.0
# Johnson High School    [District]            4761            3094650.0
#
#                        Per Student Budget  Average Math Score  \
# School Name
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# School Name
# ...

# %%
#Math Scores by grade at each school
ninth = combined_df.loc[combined_df['grade'] == '9th'].groupby('school_name')
ninth.head()
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 12             12  Brittney Walker      F   9th   Huang High School
# 13             13     William Long      M   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 37537       37537      Erik Snyder      M   9th  Thomas High School
# 37538       37538   Tanya Martinez      F   9th  Thomas High School
# 37539       37539    Noah Erickson      M   9th  Thomas High School
# 37540       37540     Austin Meyer      M   9th  Thomas High School
# 37543       37543  Madison Hampton      F   9th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
tenth = combined_df.loc[combined_df['grade'] == '10th'].groupby('school_name')
eleventh = combined_df.loc[combined_df['grade'] == '11th'].groupby('school_name')
twelfth = combined_df.loc[combined_df['grade'] == '12th'].groupby('school_name')

# %%
# Math score by grade DataFrame
math_by_grade_df= pd.DataFrame({
    '9th Grade': ninth['math_score'].mean(),
    '10th Grade': tenth['math_score'].mean(),
    '11th Grade': eleventh['math_score'].mean(),
    '12th Grade': twelfth['math_score'].mean()
})
math_by_grade_df
# Out:
#                        9th Grade  10th Grade  11th Grade  12th Grade
# school_name
# Bailey High School     77.083676   76.996772   77.515588   76.492218
# Cabrera High School    83.094697   83.154506   82.765560   83.277487
# Figueroa High School   76.403037   76.539974   76.884344   77.151369
# Ford High School       77.361345   77.672316   76.918058   76.179963
# Griffin High School    82.044010   84.229064   83.842105   83.356164
# Hernandez High School  77.438495   77.337408   77.136029   77.186567
# Holden High School     83.787402   83.429825   85.000000   82.855422
# Huang High School      77.027251   75.908735   76.446602   77.225641
# Johnson High School    77.187857   76.691117   77.491653   76.863248
# Pena High School       83.625455   83.372000   84.328125   84.121547
# Rodriguez High School  76.859966   76.612500   76.395626   77.690748
# Shelton High School    83.420755   82.917411   83.383495   83.778976
# ...

# %%
#Reading scores by grade per school DataFrame

reading_by_grade_df= pd.DataFrame({
    '9th Grade': ninth['reading_score'].mean(),
    '10th Grade': tenth['reading_score'].mean(),
    '11th Grade': eleventh['reading_score'].mean(),
    '12th Grade': twelfth['reading_score'].mean()
})
reading_by_grade_df
# Out:
#                        9th Grade  10th Grade  11th Grade  12th Grade
# school_name
# Bailey High School     81.303155   80.907183   80.945643   80.912451
# Cabrera High School    83.676136   84.253219   83.788382   84.287958
# Figueroa High School   81.198598   81.408912   80.640339   81.384863
# Ford High School       80.632653   81.262712   80.403642   80.662338
# Griffin High School    83.369193   83.706897   84.288089   84.013699
# Hernandez High School  80.866860   80.660147   81.396140   80.857143
# Holden High School     83.677165   83.324561   83.815534   84.698795
# Huang High School      81.290284   81.512386   81.417476   80.305983
# Johnson High School    81.260714   80.773431   80.616027   81.227564
# Pena High School       83.807273   83.612000   84.335938   84.591160
# Rodriguez High School  80.993127   80.629808   80.864811   80.376426
# Shelton High School    84.122642   83.441964   84.373786   82.781671
# ...

# %%
# creating bins for school spending per student
school_bins = school_summary_df.copy()
bins = [0, 585, 630, 645, 680]
ranges = ['<$585', '$585-630', '$630-645', '$645-680']

# %%
school_bins['Ranges for Spending Per Student'] = pd.cut(school_bins['Per Student Budget'], bins, labels= ranges, include_lowest = True)
school_bins1 = school_bins.iloc[:,4:10].groupby('Ranges for Spending Per Student')
school_bins1.mean()
# Out:
#                                  Average Math Score  Average Reading Score  \
# Ranges for Spending Per Student
# <$585                                     83.455399              83.933814
# $585-630                                  81.899826              83.155286
# $630-645                                  78.518855              81.624473
# $645-680                                  76.997210              81.027843
#
#                                  % Passing Math  % Passing Reading  \
# Ranges for Spending Per Student
# <$585                                 93.460096          96.610877
# $585-630                              87.133538          92.718205
# $630-645                              73.484209          84.391793
# $645-680                              66.164813          81.133951
#
#                                  % Overall Passing
# Ranges for Spending Per Student
# <$585                                    90.369459
# ...

# %%
# bins for school size
school_size_bins = school_summary_df.copy()
size_bins = [0, 1000, 2000, 5000]
size_ranges = ['Small (<1000)', 'Medium (1000-2000)', 'Large (2000-5000)']

# %%
school_size_bins['School Size Ranges'] = pd.cut(school_size_bins['Total Students'], size_bins, labels = size_ranges, include_lowest= True)
school_size_bins1 = school_size_bins.iloc[:, 4:10].groupby('School Size Ranges')
school_size_bins1.mean()
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size Ranges
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size Ranges
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %%
#scores by school type 
scores_by_type = school_summary_df.copy()
scores_by_type1 = scores_by_type.iloc[:,4:10]
scores_by_type1['School Type'] = school_summary_df['School Type']
scores_by_type1.groupby('School Type').mean()
# Out:
#               Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# ['Charter']            83.473852              83.896421       93.620830
# ['District']           76.956733              80.966636       66.548453
#
#               % Passing Reading  % Overall Passing
# School Type
# ['Charter']           96.586489          90.432244
# ['District']          80.799062          53.672208
